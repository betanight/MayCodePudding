# %% [markdown]
# # Scraped Data Analysis

# %%
import os
import numpy as np
import pandas as pd
from tqdm import tqdm

import matplotlib.pyplot as plt
import seaborn as sns

import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from textblob import TextBlob
import spacy

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, roc_auc_score
from sklearn.model_selection import GridSearchCV

import torch
from transformers import AutoTokenizer, AutoModel, pipeline

import openpyxl
import xlrd

# Just in case
import requests
from bs4 import BeautifulSoup

pd.set_option('display.max_colwidth', None)

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\kenklabnik\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kenklabnik\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
spacy.load('en_core_web_sm')

# %%
dataset_path = os.path.join(os.pardir, 'scraped_data')

df = pd.read_csv(os.path.join(dataset_path, 'wiki_bias_predictions.csv'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 dataset_path = os.path.join(os.pardir, 'scraped_data')
# ----> 3 df = pd.read_csv(os.path.join(dataset_path, 'wiki_bias_predictions.csv'))
#
# File f:\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File f:\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File f:\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File f:\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File f:\anaconda3\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '..\\scraped_data\\wiki_bias_predictions.csv'

# %%
df.head()
# Out:
#                                                                                                                                                                                combined_text  \
# 0                                       Donald John Trump (born June 14, 1946) is an American politician, media personality, and businessman who is the 47th president of the United States.
# 1                                                                                                       A member of the Republican Party, he served as the 45th president from 2017 to 2021.
# 2                      Born into a wealthy family in the New York City borough of Queens, Trump graduated from the University of Pennsylvania in 1968 with a bachelor's degree in economics.
# 3  He became the president of his family's real estate business in 1971, renamed it the Trump Organization, and began acquiring and building skyscrapers, hotels, casinos, and golf courses.
# 4                                                                  He launched side ventures, many licensing the Trump name, and filed for six business bankruptcies in the 1990s and 2000s.
#
#    bias_word_count  lexicon_match_count     outlet     topic    type  \
# 0                0                    0  usa-today  politics  center
# 1                0                    0  usa-today  politics  center
# 2                0                    0  usa-today  politics  center
# 3                0                    0  usa-today  politics  center
# 4                0                    0  usa-today  politics  center
#
#                            label_opinion  bias_prediction  bias_probability  \
# 0  Somewhat factual but also opinionated                0          0.283093
# 1  Somewhat factual but also opinionated                0          0.270619
# 2  Somewhat factual but also opinionated                0          0.415372
# 3  Somewhat factual but also opinionated                0          0.296700
# 4  Somewhat factual but also opinionated                0          0.272795
#
#   article_title  sentence_index
# 0  Donald Trump               0
# 1  Donald Trump               1
# 2  Donald Trump               2
# 3  Donald Trump               3
# 4  Donald Trump               4

# %%
df['bias_probability'].min(), df['bias_probability'].max()
# Out:
# (np.float64(0.0814672196601992), np.float64(0.579719237932214))

# %% [markdown]
# ────────────────────────────────────────────────────────────────────────────
#
# This shows the range of bias probabilities in the new Wikipedia dataset.
#
# The lowest predicted bias probability is about **0.081**, and the highest is around **0.580**.
# This tells us that most sentences in Wikipedia articles are predicted to be **low in bias**, which makes sense given Wikipedia’s neutral writing style.
# However, the presence of higher values near **0.58** shows that the model is still able to detect subtle bias in some sentences.
#
# ────────────────────────────────────────────────────────────────────────────

# %%
df['bias_prediction'].value_counts()
# Out:
# bias_prediction
# 0    17686
# 1       15
# Name: count, dtype: int64

# %% [markdown]
# ────────────────────────────────────────────────────────────────────────────
#
# This shows how many sentences were flagged as biased in the new Wikipedia dataset.
#
# Out of **17,701 total sentences**, only **15** were labeled as biased (`1`).
# This is a very small portion, which matches expectations — Wikipedia aims for a neutral tone, and the model was trained to be careful about labeling something as biased.
# The few biased predictions likely represent sentences with subtle framing, emotionally charged language, or controversial phrasing.
#
# ────────────────────────────────────────────────────────────────────────────

# %%
biased_rows = df[df['bias_prediction'] == 1]
biased_rows.head(15)
# Out:
#                                                                                                                                                                                                                                                      combined_text  \
# 4083                                                                                                                                                                                                                                             New York: Harper.
# 4112                                                                                                       The abortion issue gained renewed attention in 2011 in a debate that The New York Times says "has begun to sound like the debate in the United States".
# 4146                                                                                                                       Anti-abortion groups like Students for Life of America and Susan B. Anthony Pro-Life America are at times associated with conservatism.
# 6234                                                                                                                                                                                                                                          New York: Routledge.
# 6242                                                                                                                                                                                                                                                New York: E.P.
# 8810                                                                                                                                                                                                                                                       Trump."
# 9013                                                                                                                                                                               The New York Times (NYT) is an American daily newspaper based in New York City.
# 9029                                                                                           It has expanded to several other publications, including The New York Times Magazine, The New York Times International Edition, and The New York Times Book Review.
# 9049   The Great Depression forced Sulzberger to reduce The New York Times's operations, and developments in the New York newspaper landscape resulted in the formation of larger newspapers, such as the New York Herald Tribune and the New York World-Telegram.
# 9079                                                                                                               The exodus of readers to suburban New York newspapers, such as Newsday and Gannett papers, adversely affected The New York Times's circulation.
# 9236                                                                                                                                                  Additionally, The New York Times has maintained a virtual microfilm reader known as TimesMachine since 2014.
# 10579                                                                                                                                                                                                                                  Londen/New York: Routledge.
# 13399                                                                                                                                                                                                                                         New York: HarperOne.
# 17659                                                                                                                                                                                                                                London; New York: Bloomsbury.
# 17698                                                                                                                                                                                                                                       New York: Verso, 2004.
#
#        bias_word_count  lexicon_match_count     outlet     topic    type  \
# 4083                 0                    0  usa-today  politics  center
# 4112                 0                    0  usa-today  politics  center
# 4146                 0                    0  usa-today  politics  center
# 6234                 0                    0  usa-today  politics  center
# 6242                 0                    0  usa-today  politics  center
# 8810                 0                    0  usa-today  politics  center
# 9013                 0                    0  usa-today  politics  center
# 9029                 0                    0  usa-today  politics  center
# 9049                 0                    0  usa-today  politics  center
# 9079                 0                    0  usa-today  politics  center
# 9236                 0                    0  usa-today  politics  center
# 10579                0                    0  usa-today  politics  center
# 13399                0                    0  usa-today  politics  center
# 17659                0                    0  usa-today  politics  center
# 17698                0                    0  usa-today  politics  center
#
#                                label_opinion  bias_prediction  \
# 4083   Somewhat factual but also opinionated                1
# 4112   Somewhat factual but also opinionated                1
# 4146   Somewhat factual but also opinionated                1
# 6234   Somewhat factual but also opinionated                1
# 6242   Somewhat factual but also opinionated                1
# 8810   Somewhat factual but also opinionated                1
# 9013   Somewhat factual but also opinionated                1
# 9029   Somewhat factual but also opinionated                1
# 9049   Somewhat factual but also opinionated                1
# 9079   Somewhat factual but also opinionated                1
# 9236   Somewhat factual but also opinionated                1
# 10579  Somewhat factual but also opinionated                1
# 13399  Somewhat factual but also opinionated                1
# 17659  Somewhat factual but also opinionated                1
# 17698  Somewhat factual but also opinionated                1
#
#        bias_probability                           article_title  \
# 4083           0.549528                                   QAnon
# 4112           0.546173                                Pro-life
# 4146           0.510336                                Pro-life
# 6234           0.549528        Immigration to the United States
# 6242           0.549528        Immigration to the United States
# 8810           0.579719                          Breitbart News
# 9013           0.540670                      The New York Times
# 9029           0.514546                      The New York Times
# 9049           0.509814                      The New York Times
# 9079           0.515060                      The New York Times
# 9236           0.512174                      The New York Times
# 10579          0.549528                             Ukraine war
# 13399          0.549528  Religious freedom in the United States
# 17659          0.522817                            War on drugs
# 17698          0.549528                            War on drugs
#
#        sentence_index
# 4083              678
# 4112               19
# 4146               53
# 6234              480
# 6242              488
# 8810               53
# 9013                0
# 9029               16
# 9049               36
# 9079               66
# 9236              223
# 10579              30
# 13399             313
# 17659             575
# 17698             614

# %% [markdown]
# ────────────────────────────────────────────────────────────────────────────
#
# These are the 15 sentences the model identified as biased across all the Wikipedia topics it scanned.
#
# Each sentence received a `bias_probability` above the threshold of **0.33**, meaning the model found subtle signs of bias — even if the sentence seems neutral at first glance.
#
# Interestingly, several of the flagged sentences are **publisher references** (e.g., "New York: Harper.") which likely tripped the model due to patterns seen during training. Others, like the sentences from the **Pro-life** or **New York Times** articles, contain phrases that reflect **political framing, media associations, or ideological links**.
#
# This small set of predictions shows that while most of Wikipedia is neutral, the model is capable of identifying nuanced or structurally biased content in a consistent, careful way.
#
# ────────────────────────────────────────────────────────────────────────────
